# %% [markdown]
# Build the lgbt model via following features
#
# 1. lag/mean encoding (numerical) features
# 2. text <-- What we are going to build in this notebook
#     - tfidf + truncated svd
#     - hashing  + truncated svd

# %%
import pandas as pd 
import numpy as np 
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
import gc
gc.enable()

# %%
with pd.HDFStore('../data/feat/data.h5') as store:
    print(store.keys())
    X_train = store['X_train']
    X_cv = store['X_cv']
    y_train = store['y_train']
    y_cv = store['y_cv']
    X_test = store['X_test']
# Out:
# ['/X_cv', '/X_test', '/X_train', '/y_cv', '/y_train']

# %%
y_train = y_train.clip(0,20)
y_cv = y_cv.clip(0,20)

# %% [markdown]
# ## Text data processing
# process raw text with tfidf(b)/hashing svd

# %%
with pd.HDFStore('../data/feat/text_feats.h5') as text_io:
    print(text_io.keys())
    X_text_feats_test = text_io['X_text_feats_test']
    X_text_feats_cv = text_io['X_text_feats_cv']
    X_text_feats_train = text_io['X_text_feats_train']
# Out:
# ['/X_text_feats', '/X_text_feats_cv', '/X_text_feats_test', '/X_text_feats_train']

# %%
X_text_feats_train.shape
# Out:
# (10675632, 4)

# %%
train_text_df = pd.concat([X_text_feats_train,X_text_feats_cv])
test_text_df = X_text_feats_test

train_texts = train_text_df['item_name'] + ' ' + train_text_df['item_category_name'] + ' ' + train_text_df['shop_name']
test_texts = test_text_df['item_name'] + ' ' + test_text_df['item_category_name'] + ' ' + test_text_df['shop_name']

# %%
all_texts = pd.Series(np.concatenate([train_texts, test_texts], axis=0))
del train_text_df, test_text_df, train_texts, test_texts; gc.collect()
all_texts.shape
# Out:
# (11128004,)

# %%
del X_text_feats_train, X_text_feats_cv, X_text_feats_test; gc.collect()
# Out:
# 29

# %% [markdown]
# ### 1. Tfidf + truncated svd

# %%
## tfidf 
from sklearn.feature_extraction.text import TfidfVectorizer
tv = TfidfVectorizer(lowercase=False, ngram_range=(1,2))

tv_features = tv.fit_transform(all_texts)
print('shape of tfidf Vectorizer:{}'.format(tv_features.shape))

### svd 
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=20, random_state=0)
tv_svd_features = svd.fit_transform(tv_features)

## memory used
import sys
print('memory used (tv_svd_features):{}'.format(sys.getsizeof(tv_svd_features)/(1024*1024*1024)))
# Out:
# shape of tfidf Vectorizer:(11128004, 77634)
# memory used (tv_svd_features):1.6582019180059433

# %%
del svd; tv_features; gc.collect()
# Out:
# 897

# %% [markdown]
# ### 2. binarize Tfidf  + truncated svd

# %%
## binary tfidf
tvb_features = tv_features.astype(bool).astype(float)

## svd
svd = TruncatedSVD(n_components=20, random_state=0)
tvb_svd_features = svd.fit_transform(tvb_features)
print('shape of tvb features:{}'.format(tvb_svd_features.shape))
print('memory used (tvb_svd_features):{}'.format(sys.getsizeof(tvb_svd_features)/(1024*1024*1024)))
# Out:
# shape of tvb features:(11128004, 20)
# memory used (tvb_svd_features):1.6582019180059433

# %%
del svd, tvb_features; gc.collect();

# %% [markdown]
# ### 3. Hashing + truncated svd

# %%
from sklearn.feature_extraction.text import HashingVectorizer
hv = HashingVectorizer(ngram_range=(1, 2), lowercase=False)
hv_features = hv.fit_transform(all_texts).tocsr()
print('shape of hv features:{}'.format(hv_features.shape))

svd = TruncatedSVD(n_components=20, random_state=0)
hv_svd_features = svd.fit_transform(hv_features)

print('memory used (hv_svd_features):{:.3f}'.format(sys.getsizeof(hv_svd_features)/(1024*1024*1024)))
# Out:
# shape of hv features:(11128004, 1048576)
# memory used (hv_svd_features):1.658

# %% [markdown]
# ### 4. Binary Hasing + Truncated svd

# %%
hvb_features = hv_features.astype(bool).astype(float)

svd = TruncatedSVD(n_components=20, random_state=0)
hvb_svd_features = svd.fit_transform(hvb_features)

print(sys.getsizeof(hvb_svd_features)/(1024*1024*1024))
del hvb_features; gc.collect()
# Out:
# 1.6582019180059433
# 65

# %% [markdown]
# ### 5. Stack 1-4 and save

# %%
text_features = np.concatenate([tv_svd_features, tvb_svd_features, hv_svd_features, hvb_svd_features], axis=1)

print('memory used for all text_features:{:3f}'.format(sys.getsizeof(text_features)/(1024*1024*1024)))
# Out:
# memory used for all text_features:6.632807

# %%
del tv_svd_features,tvb_svd_features,hv_svd_features,hvb_svd_features; gc.collect()
# Out:
# 3543

# %%
text_features_df = pd.DataFrame(data=text_features, columns=['text_f_'+str(i) for i in range(80)])

# %%
text_features_df.head()
# Out:
#    text_f_0  text_f_1  text_f_2  text_f_3  text_f_4  text_f_5  text_f_6  \
# 0  0.277484 -0.173652 -0.063240 -0.090207 -0.023441 -0.013428 -0.019452
# 1  0.039884  0.027490  0.048064 -0.010053 -0.005663 -0.008881 -0.013801
# 2  0.029936  0.017483  0.032786 -0.004073 -0.004317 -0.006618 -0.011949
# 3  0.065214  0.058522  0.142886 -0.053096 -0.019396 -0.012969 -0.012155
# 4  0.043049  0.019077  0.038894  0.023213 -0.013758 -0.010637 -0.013122
#
#    text_f_7  text_f_8  text_f_9    ...      text_f_70  text_f_71  text_f_72  \
# 0  0.007843 -0.021224  0.023921    ...      -0.033810  -0.234008  -0.110437
# 1  0.008955 -0.008782  0.018617    ...       0.050828  -0.241337  -0.108003
# 2  0.008032 -0.008361  0.019091    ...       0.053172  -0.237839  -0.102671
# 3  0.005954 -0.010409  0.008706    ...       0.017964  -0.241615  -0.115704
# 4  0.005971 -0.012691  0.017750    ...       0.027809  -0.240677  -0.094627
#
#    text_f_73  text_f_74  text_f_75  text_f_76  text_f_77  text_f_78  text_f_79
# 0  -0.110263  -0.022642  -0.003122   0.056965   0.105615   0.012552   0.030759
# 1  -0.252701  -0.059449   0.121994  -0.172504   0.083715  -0.342954   0.627240
# 2  -0.253724  -0.060433   0.113566  -0.164430   0.098105  -0.327809   0.576223
# 3  -0.125150  -0.025767   0.021801  -0.000432   0.083451  -0.112115   0.189098
# 4  -0.177729  -0.043124   0.047342  -0.066383   0.108523  -0.167366   0.356736
#
# [5 rows x 80 columns]

# %%
text_io = pd.HDFStore('../data/feat/text_feat_df_all.h5') ###
text_io['text_feats_df'] = text_features_df
text_io.close()

# %% [markdown]
# #### merge all features in a single table

# %%
text_features_df.shape[0] == X_train.shape[0] + X_cv.shape[0] + X_test.shape[0]
# Out:
# True

# %%
merge = pd.concat([X_train,X_cv,X_test])

# %%
merge = pd.concat([merge, text_features_df],axis=1)## merge in axis=1

# %%
merge.head().T
# Out:
#                                                     0            1  \
# shop_id                                     59.000000    59.000000
# item_id                                  22154.000000  2552.000000
# date_block_num                               0.000000     0.000000
# item_category_id                            37.000000    58.000000
# item_id_avg_item_price_lag_1                      NaN          NaN
# item_id_sum_item_cnt_day_lag_1                    NaN          NaN
# item_id_avg_item_cnt_day_lag_1                    NaN          NaN
# shop_id_avg_item_price_lag_1                      NaN          NaN
# shop_id_sum_item_cnt_day_lag_1                    NaN          NaN
# shop_id_avg_item_cnt_day_lag_1                    NaN          NaN
# item_category_id_avg_item_price_lag_1             NaN          NaN
# item_category_id_sum_item_cnt_day_lag_1           NaN          NaN
# item_category_id_avg_item_cnt_day_lag_1           NaN          NaN
# item_cnt_month_lag_1                              NaN          NaN
# item_id_avg_item_price_lag_2                      NaN          NaN
# item_id_sum_item_cnt_day_lag_2                    NaN          NaN
# item_id_avg_item_cnt_day_lag_2                    NaN          NaN
# shop_id_avg_item_price_lag_2                      NaN          NaN
# shop_id_sum_item_cnt_day_lag_2                    NaN          NaN
# shop_id_avg_item_cnt_day_lag_2                    NaN          NaN
# item_category_id_avg_item_price_lag_2             NaN          NaN
# item_category_id_sum_item_cnt_day_lag_2           NaN          NaN
# item_category_id_avg_item_cnt_day_lag_2           NaN          NaN
# item_cnt_month_lag_2                              NaN          NaN
# item_id_avg_item_price_lag_3                      NaN          NaN
# item_id_sum_item_cnt_day_lag_3                    NaN          NaN
# item_id_avg_item_cnt_day_lag_3                    NaN          NaN
# shop_id_avg_item_price_lag_3                      NaN          NaN
# shop_id_sum_item_cnt_day_lag_3                    NaN          NaN
# shop_id_avg_item_cnt_day_lag_3                    NaN          NaN
# ...                                               ...          ...
# text_f_50                                    0.023888     0.021843
# text_f_51                                   -0.000884    -0.008202
# text_f_52                                    0.007852    -0.006946
# text_f_53                                   -0.028447    -0.004652
# text_f_54                                   -0.027655    -0.061663
# text_f_55                                    0.016709     0.015490
# text_f_56                                   -0.004758    -0.121260
# text_f_57                                    0.002737    -0.008614
# text_f_58                                   -0.004069    -0.009557
# text_f_59                                   -0.044023    -0.098643
# text_f_60                                    1.716856     0.857258
# text_f_61                                   -1.419964     0.379053
# text_f_62                                   -0.857779     0.114839
# text_f_63                                    1.390751    -0.032052
# text_f_64                                    0.120604     0.472678
# text_f_65                                   -0.392141    -0.475331
# text_f_66                                    0.056630    -0.037671
# text_f_67                                   -0.161157     0.139454
# text_f_68                                    0.047195    -0.011811
# text_f_69                                   -0.107322    -0.030551
# text_f_70                                   -0.033810     0.050828
# text_f_71                                   -0.234008    -0.241337
# text_f_72                                   -0.110437    -0.108003
# text_f_73                                   -0.110263    -0.252701
# text_f_74                                   -0.022642    -0.059449
# text_f_75                                   -0.003122     0.121994
# text_f_76                                    0.056965    -0.172504
# text_f_77                                    0.105615     0.083715
# text_f_78                                    0.012552    -0.342954
# text_f_79                                    0.030759     0.627240
#
#                                                    2            3            4
# shop_id                                    59.000000    59.000000    59.000000
# item_id                                  2554.000000  2555.000000  2564.000000
# date_block_num                              0.000000     0.000000     0.000000
# item_category_id                           58.000000    56.000000    59.000000
# item_id_avg_item_price_lag_1                     NaN          NaN          NaN
# item_id_sum_item_cnt_day_lag_1                   NaN          NaN          NaN
# item_id_avg_item_cnt_day_lag_1                   NaN          NaN          NaN
# shop_id_avg_item_price_lag_1                     NaN          NaN          NaN
# shop_id_sum_item_cnt_day_lag_1                   NaN          NaN          NaN
# shop_id_avg_item_cnt_day_lag_1                   NaN          NaN          NaN
# item_category_id_avg_item_price_lag_1            NaN          NaN          NaN
# item_category_id_sum_item_cnt_day_lag_1          NaN          NaN          NaN
# item_category_id_avg_item_cnt_day_lag_1          NaN          NaN          NaN
# item_cnt_month_lag_1                             NaN          NaN          NaN
# item_id_avg_item_price_lag_2                     NaN          NaN          NaN
# item_id_sum_item_cnt_day_lag_2                   NaN          NaN          NaN
# item_id_avg_item_cnt_day_lag_2                   NaN          NaN          NaN
# shop_id_avg_item_price_lag_2                     NaN          NaN          NaN
# shop_id_sum_item_cnt_day_lag_2                   NaN          NaN          NaN
# shop_id_avg_item_cnt_day_lag_2                   NaN          NaN          NaN
# item_category_id_avg_item_price_lag_2            NaN          NaN          NaN
# item_category_id_sum_item_cnt_day_lag_2          NaN          NaN          NaN
# item_category_id_avg_item_cnt_day_lag_2          NaN          NaN          NaN
# item_cnt_month_lag_2                             NaN          NaN          NaN
# item_id_avg_item_price_lag_3                     NaN          NaN          NaN
# item_id_sum_item_cnt_day_lag_3                   NaN          NaN          NaN
# item_id_avg_item_cnt_day_lag_3                   NaN          NaN          NaN
# shop_id_avg_item_price_lag_3                     NaN          NaN          NaN
# shop_id_sum_item_cnt_day_lag_3                   NaN          NaN          NaN
# shop_id_avg_item_cnt_day_lag_3                   NaN          NaN          NaN
# ...                                              ...          ...          ...
# text_f_50                                   0.015748     0.013318     0.015498
# text_f_51                                  -0.009119    -0.002035    -0.003074
# text_f_52                                  -0.008326     0.006706     0.000571
# text_f_53                                  -0.006726    -0.019203    -0.012786
# text_f_54                                  -0.058257    -0.026111    -0.037322
# text_f_55                                   0.014749     0.014903     0.012505
# text_f_56                                  -0.112425    -0.033188    -0.055557
# text_f_57                                  -0.007689    -0.004140    -0.006845
# text_f_58                                  -0.006981    -0.008404    -0.013125
# text_f_59                                  -0.092214    -0.047728    -0.063323
# text_f_60                                   0.811190     1.409463     1.011775
# text_f_61                                   0.321098     1.333038     0.133597
# text_f_62                                   0.106605    -0.220652     0.070472
# text_f_63                                  -0.043416     0.043959    -0.487986
# text_f_64                                   0.485410     0.190553     0.274273
# text_f_65                                  -0.475412    -0.431962    -0.453373
# text_f_66                                  -0.046242    -0.002579    -0.017708
# text_f_67                                   0.134196    -0.002034     0.044938
# text_f_68                                   0.018174     0.091001     0.064481
# text_f_69                                  -0.054462    -0.100156    -0.085125
# text_f_70                                   0.053172     0.017964     0.027809
# text_f_71                                  -0.237839    -0.241615    -0.240677
# text_f_72                                  -0.102671    -0.115704    -0.094627
# text_f_73                                  -0.253724    -0.125150    -0.177729
# text_f_74                                  -0.060433    -0.025767    -0.043124
# text_f_75                                   0.113566     0.021801     0.047342
# text_f_76                                  -0.164430    -0.000432    -0.066383
# text_f_77                                   0.098105     0.083451     0.108523
# text_f_78                                  -0.327809    -0.112115    -0.167366
# text_f_79                                   0.576223     0.189098     0.356736
#
# [134 rows x 5 columns]

# %% [markdown]
# #### save it as `all_features` tables

# %%
text_io = pd.HDFStore('../data/feat/all_feat_df_all.h5') ###
text_io['all_feats_df_all'] = merge
text_io.close()

# %% [markdown]
# _____
